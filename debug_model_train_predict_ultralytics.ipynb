# %%
"""
下载 PASCAL VOC 2007 数据集并转换为 YOLO 格式,生成 voc.yaml 文件
PASCAL VOC 2007 数据集是计算机视觉领域中一个著名的标准数据集，主要用于目标检测、图像分类和语义分割等任务。
该数据集包含 9963 张图片，分为训练集（5011 张）和测试集（4952 张），
涵盖 20 个类别，如飞机、自行车、鸟、船、瓶子、公共汽车、汽车、猫、椅子、牛、餐桌、狗、马、摩托车、人、盆栽、羊、沙发、火车和电视显示器。
其标注信息以 XML 格式存储，包含目标的边界框、类别标签等。该数据集是许多经典计算机视觉模型的训练和评估基准。
"""
import os
import requests
import tarfile
from lxml import etree
import shutil

# ----------------------
# 配置参数
# ----------------------
VOC_URL = "http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar"
VOC_TEST_URL = "http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar"
DATA_DIR = "./dataset/"

# ----------------------
# 下载并解压数据集
# ----------------------
def download_and_extract(url, dest_dir):
    if not os.path.exists(dest_dir):
        os.makedirs(dest_dir, exist_ok=True)

    filename = os.path.join(dest_dir, url.split("/")[-1])

    # 下载文件
    if not os.path.exists(filename):
        print(f"Downloading {url}...")
        response = requests.get(url, stream=True)
        with open(filename, "wb") as f:
            for chunk in response.iter_content(chunk_size=1024):
                if chunk:
                    f.write(chunk)

    # 解压文件
    print(f"Extracting {filename}...")
    with tarfile.open(filename) as tar:
        tar.extractall(path=dest_dir)



# 转换VOC格式到YOLO格式
# ----------------------
def convert_voc_to_yolo(voc_dir, output_dir):
    print(f"转换VOC格式到YOLO格式: {output_dir}")

    classes = [
        'aeroplane', 'bicycle', 'bird', 'boat', 'bottle',
        'bus', 'car', 'cat', 'chair', 'cow',
        'diningtable', 'dog', 'horse', 'motorbike', 'person',
        'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor'
    ]

    # 创建训练和测试子目录
    for split in ["train", "test"]:
        os.makedirs(os.path.join(output_dir, f"images/{split}"), exist_ok=True)
        os.makedirs(os.path.join(output_dir, f"labels/{split}"), exist_ok=True)

    # 对 trainval 和 test 分别处理
    for split in ["trainval", "test"]:
        split_type = "train" if split == "trainval" else "test"
        list_path = os.path.join(voc_dir, f"VOCdevkit/VOC2007/ImageSets/Main/{split}.txt")
        if not os.path.exists(list_path):
            print(f"划分文件不存在: {list_path}")
            continue

        with open(list_path) as f:
            ids = [line.strip() for line in f.readlines()]
        print(f"开始处理 {split_type} 集，共 {len(ids)} 张图片")

        for img_id in ids:
            ann_path = os.path.join(voc_dir, f"VOCdevkit/VOC2007/Annotations/{img_id}.xml")
            if not os.path.exists(ann_path):
                print(f"标注文件不存在: {ann_path}")
                continue

            tree = etree.parse(ann_path)
            root = tree.getroot()

            size = root.find("size")
            width = int(size.find("width").text)
            height = int(size.find("height").text)

            yolo_ann = []
            for obj in root.iter("object"):
                cls = obj.find("name").text
                if cls not in classes:
                    continue
                cls_id = classes.index(cls)

                bbox = obj.find("bndbox")
                xmin = float(bbox.find("xmin").text)
                ymin = float(bbox.find("ymin").text)
                xmax = float(bbox.find("xmax").text)
                ymax = float(bbox.find("ymax").text)

                x_center = (xmin + xmax) / 2 / width
                y_center = (ymin + ymax) / 2 / height
                w = (xmax - xmin) / width
                h = (ymax - ymin) / height

                yolo_ann.append(f"{cls_id} {x_center:.6f} {y_center:.6f} {w:.6f} {h:.6f}")

            # 保存 YOLO 标签
            label_out_path = os.path.join(output_dir, f"labels/{split_type}/{img_id}.txt")
            with open(label_out_path, "w") as f:
                f.write("\n".join(yolo_ann))

            # 拷贝图像
            src = os.path.join(voc_dir, f"VOCdevkit/VOC2007/JPEGImages/{img_id}.jpg")
            dst = os.path.join(output_dir, f"images/{split_type}/{img_id}.jpg")
            if not os.path.exists(dst):
                try:
                    shutil.copy2(src, dst)
                    # os.symlink(src, dst)  # 尝试创建符号链接
                except:
                    print(f"复制图像失败: {src}")

    # 创建 voc.yaml 文件
    with open("voc.yaml", "w") as f:
        names_str = '\n'.join([f"  {i}: {name}" for i, name in enumerate(classes)])
        f.write(
f"""path: {os.path.abspath(output_dir)}
train: images/train
val: images/train
test: images/test
names:
{names_str}
"""
        )
    print("✅ VOC 转 YOLO 完成，生成 voc.yaml")


# # 下载并解压训练集和测试集
download_and_extract(VOC_URL, DATA_DIR)
download_and_extract(VOC_TEST_URL, DATA_DIR)
# # 执行格式转换 voc->yolo
convert_voc_to_yolo(DATA_DIR, DATA_DIR+"/output")
# Out:
# Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtrainval_06-Nov-2007.tar...
# Extracting ./dataset/VOCtrainval_06-Nov-2007.tar...
# Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2007/VOCtest_06-Nov-2007.tar...
# Extracting ./dataset/VOCtest_06-Nov-2007.tar...
# 转换VOC格式到YOLO格式: ./dataset//output
# 开始处理 train 集，共 5011 张图片
# 开始处理 test 集，共 4952 张图片
# ✅ VOC 转 YOLO 完成，生成 voc.yaml

# %%
"""
基于YOLO V8的PASCAL VOC 2007的目标检测任务
"""
# !pip install ultralytics
# 使用预训练模型
from ultralytics import YOLO
from PIL import Image, ImageDraw, ImageFont
device = 'cuda'  # 使用GPU训练,可选cuda或cpu

# !nvidia-smi
# 加载预训练模型
model = YOLO("baseModel/yolov8n.pt")  # 使用预训练模型
print("模型加载完成") if model else print("模型加载失败")
# 训练模型
# 训练参数配置
model.train(
    data='voc.yaml',
    epochs=100,  # 训练轮数
    batch=64,   # 批处理大小
    imgsz=800,  # 输入图像大小
    device=0 if device == "cuda" else "cpu",
    optimizer='AdamW',  # 优化器
    lr0=0.0001, # 初始学习率,可选0.001、0.01、0.1等
    lrf=0.005,
    warmup_epochs=3,   # 新增学习率预热
    weight_decay=0.05,           # 添加权重衰减防止过拟合

    augment=True,
    hsv_h=0.3,                   # 增强色调扰动
    hsv_s=0.6,                   # 增强饱和度扰动
    translate=0.2,               # 增大平移幅度
    scale=0.5,                   # 扩大缩放范围
    shear=0.3,                   # 增大剪切幅度
    mosaic=1.0,                  # 全程开启mosaic
    close_mosaic=15,             # 最后15个epoch关闭mosaic稳定训练
    augment=True,
    # 损失函数调整
    cls=3.0,                     # 增大分类损失权重
    box=1.5,                     # 增大框回归损失权重
    dfl=1.5,                     # 增大点框损失权重
    mixup=0.2,       # 新增MixUp增强（默认未启用）

    patience=15,                  # 延长早停观察期
    dropout=0.3,                 # 添加Dropout正则化
    amp=True,                    # 保持混合精度训练
    pretrained=True,
    save=True,
    exist_ok=True,
)
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.120-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.120-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.9/664.8 MB 127.8 MB/s eta 0:00:05

# %%
# 预测输出（使用OpenCV统一绘图）
import os
import cv2
import torch
from ultralytics import YOLO
import matplotlib.pyplot as plt

# ------------ 全局配置 ------------
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
MODEL_PATH = "runs/detect/train/weights/best.pt"
model = YOLO(MODEL_PATH)
# INPUT_PATH = "dataset/output/video/test.mp4"  # 输入路径，可以是图片/视频/文件夹/摄像头
# INPUT_PATH = "dataset/output/test/"
INPUT_PATH = 0
SAVE = False  # 是否保存预测结果
OUTPUT_PATH = "predict/"  # 预测结果保存路径

# ------------ 工具函数 ------------

# 使用OpenCV绘制识别框和文字
# 使用 OpenCV 绘制检测结果（根据类别动态换颜色）
def draw_boxes_cv2(image, results):
    for box in results[0].boxes:
        # 1. 取出检测框的坐标，并四舍五入为整数
        x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
        cls_id = int(box.cls)   # 获取类别ID
        conf = float(box.conf)  # 获取置信度
        label_name = model.names[cls_id]  # 获取类别名称
        label = f"{label_name} {conf:.2f}"  # 生成显示标签文本

        # 2. 决定绘制颜色
        # if label_name == "with_mask":
        #     color = (0, 255, 0)      # 绿色 (BGR)
        # elif label_name == "without_mask":
        #     color = (0, 0, 255)      # 红色 (BGR)
        # else:
        #     color = (0, 165, 255)    # 橙色 (BGR)
        color = (0, 0, 255)      # 红色 (BGR)

        # 3. 绘制矩形框（框颜色根据类别变化）
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)

        # 4. 绘制文字背景矩形（填充背景色）
        (text_w, text_h), _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)
        cv2.rectangle(image, (x1, y1 - text_h - 4), (x1 + text_w, y1), color, -1)

        # 5. 绘制白色文字（始终为白色）
        cv2.putText(image, label, (x1, y1 - 4), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)

    return image


# 保存图片
def save_image_cv2(image, save_path, origin_path=None):
    if os.path.isdir(save_path):
        filename = os.path.basename(origin_path)
        save_path = os.path.join(save_path, filename)
    else:
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
    cv2.imwrite(save_path, image)
    print(f"✅ 已保存图片: {save_path}")

# ------------ 单张图片预测 ------------
def predict_image(image_path, save=False, save_path=None):
    image = cv2.imread(image_path)
    results = model.predict(image_path, imgsz=640, device=DEVICE)
    image = draw_boxes_cv2(image, results)

    # 显示结果
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image_rgb)
    plt.axis("off")
    plt.title("预测结果")
    plt.show()

    # 保存结果
    if save and save_path:
        save_image_cv2(image, save_path, origin_path=image_path)

# ------------ 视频文件预测 ------------
def predict_video(video_path, save=False, save_path=None):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("❌ 视频文件无法打开")
        return

    if save:
        if os.path.isdir(save_path):
            filename = os.path.basename(video_path)
            save_path = os.path.join(save_path, f"{os.path.splitext(filename)[0]}.mp4")
        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        fps, w, h = cap.get(5), int(cap.get(3)), int(cap.get(4))
        out = cv2.VideoWriter(save_path, fourcc, fps, (w, h))

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = model.predict(frame, imgsz=640, device=DEVICE,verbose=False)
        frame = draw_boxes_cv2(frame, results)

        cv2.imshow("预测中 - 按 Q 退出", frame)
        if save:
            out.write(frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    if save:
        out.release()
        print(f"✅ 已保存视频: {save_path}")
    cv2.destroyAllWindows()

# ------------ 文件夹批量图片预测 ------------
# 文件夹批量预测 + 实时进度条
def predict_folder(folder_path, save=False, output_dir=None):
    # 获取全部图片文件列表
    all_files = []
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff")):
                all_files.append(os.path.join(root, file))

    total_files = len(all_files)  # 总文件数
    if total_files == 0:
        print("❌ 文件夹中没有找到图片")
        return

    # 遍历每一张图片进行预测
    for idx, img_path in enumerate(all_files, start=1):
        image = cv2.imread(img_path)
        results = model.predict(img_path, imgsz=640, device=DEVICE,verbose=False)
        image = draw_boxes_cv2(image, results)

        if save and output_dir:
            rel_path = os.path.relpath(img_path, folder_path)
            save_path = os.path.join(output_dir, rel_path)
            os.makedirs(os.path.dirname(save_path), exist_ok=True)
            cv2.imwrite(save_path, image)

        # --- 绘制进度条 ---
        progress = idx / total_files
        bar_len = 30  # 进度条长度（字符数）
        filled_len = int(bar_len * progress)
        bar = "█" * filled_len + "-" * (bar_len - filled_len)
        print(f"\r🔄 预测进度: [{bar}] {progress*100:.1f}% ({idx}/{total_files})", end="")

    # 最后换行
    print()

    if save:
        print(f"✅ 文件夹预测完成，结果已保存至: {output_dir}")


# ------------ 摄像头实时预测并可保存录像 ------------
def predict_camera(index=0, save=False, output_dir="predict/"):
    cap = cv2.VideoCapture(index)
    if not cap.isOpened():
        print(f"❌ 无法打开摄像头 {index}")
        return

    # 如果需要保存视频，初始化 VideoWriter
    if save:
        import datetime
        now = datetime.datetime.now()
        timestamp = now.strftime("%Y%m%d%H%M%S")  # 获取当前时间：年月日时分秒，纯数字
        os.makedirs(output_dir, exist_ok=True)   # 确保输出目录存在
        save_path = os.path.join(output_dir, f"camera_{index}_{timestamp}.mp4")

        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        fps = cap.get(cv2.CAP_PROP_FPS)
        if fps == 0 or fps is None:  # 有些摄像头可能取不到帧率
            fps = 30  # 默认设为30帧
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        out = cv2.VideoWriter(save_path, fourcc, fps, (width, height))

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        results = model.predict(frame, imgsz=640, device=DEVICE)
        frame = draw_boxes_cv2(frame, results)

        # 显示预测画面
        cv2.imshow("摄像头预测 - 按 Q 退出", frame)

        # 保存预测画面
        if save:
            out.write(frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    if save:
        out.release()
        print(f"✅ 摄像头视频已保存到: {save_path}")
    cv2.destroyAllWindows()


# ------------ 总入口函数 ------------
def run_predict(path, save=False, save_path=None):
    if isinstance(path, int):
        predict_camera(index=path,save=save,output_dir=save_path)
    elif os.path.isfile(path):
        ext = os.path.splitext(path)[1].lower()
        if ext in [".jpg", ".jpeg", ".png", ".bmp", ".tiff"]:
            predict_image(path, save, save_path)
        elif ext in [".mp4", ".avi", ".mov", ".mkv"]:
            predict_video(path, save, save_path)
    elif os.path.isdir(path):
        predict_folder(path, save, save_path)
    else:
        print("❌ 无效路径，请确认输入正确的图片/视频/文件夹/摄像头编号")

# ------------ 示例调用 ------------
run_predict(INPUT_PATH, SAVE, OUTPUT_PATH)
# Out:
# 0: 480x640 1 bird, 3 persons, 20.8ms
# Speed: 28.6ms preprocess, 20.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 18.4ms
# Speed: 3.1ms preprocess, 18.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 17.7ms
# Speed: 2.5ms preprocess, 17.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 17.8ms
# Speed: 2.7ms preprocess, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 18.6ms
# Speed: 3.4ms preprocess, 18.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 19.8ms
# Speed: 3.3ms preprocess, 19.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 17.7ms
# Speed: 2.0ms preprocess, 17.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 17.9ms
# Speed: 2.4ms preprocess, 17.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 17.8ms
# Speed: 2.9ms preprocess, 17.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 17.9ms
# Speed: 2.2ms preprocess, 17.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 17.6ms
# Speed: 1.8ms preprocess, 17.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 17.7ms
# Speed: 2.1ms preprocess, 17.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 18.1ms
# Speed: 3.1ms preprocess, 18.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 17.8ms
# Speed: 2.0ms preprocess, 17.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 17.7ms
# Speed: 2.7ms preprocess, 17.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 17.7ms
# Speed: 2.2ms preprocess, 17.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 18.1ms
# Speed: 2.5ms preprocess, 18.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 18.5ms
# Speed: 2.5ms preprocess, 18.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 17.9ms
# Speed: 2.3ms preprocess, 17.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 17.7ms
# Speed: 1.8ms preprocess, 17.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 17.7ms
# Speed: 2.3ms preprocess, 17.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 17.7ms
# Speed: 1.9ms preprocess, 17.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 18.1ms
# Speed: 2.3ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 18.0ms
# Speed: 1.7ms preprocess, 18.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 19.2ms
# Speed: 2.1ms preprocess, 19.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 18.9ms
# Speed: 1.8ms preprocess, 18.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.9ms
# Speed: 2.9ms preprocess, 18.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 18.7ms
# Speed: 1.7ms preprocess, 18.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 18.9ms
# Speed: 2.4ms preprocess, 18.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 4 persons, 19.0ms
# Speed: 2.5ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.8ms
# Speed: 1.8ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 19.1ms
# Speed: 2.5ms preprocess, 19.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 18.7ms
# Speed: 2.1ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 18.9ms
# Speed: 2.6ms preprocess, 18.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 18.8ms
# Speed: 3.1ms preprocess, 18.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 birds, 2 persons, 18.8ms
# Speed: 2.2ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 18.8ms
# Speed: 2.4ms preprocess, 18.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 birds, 2 persons, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 18.8ms
# Speed: 2.1ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.8ms
# Speed: 2.6ms preprocess, 18.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 birds, 2 persons, 19.1ms
# Speed: 2.0ms preprocess, 19.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.7ms
# Speed: 2.1ms preprocess, 18.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 cat, 2 persons, 18.5ms
# Speed: 2.2ms preprocess, 18.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 18.7ms
# Speed: 2.6ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 3 persons, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 19.7ms
# Speed: 2.4ms preprocess, 19.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 19.1ms
# Speed: 2.4ms preprocess, 19.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.7ms
# Speed: 1.9ms preprocess, 18.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 18.9ms
# Speed: 2.1ms preprocess, 18.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 19.2ms
# Speed: 2.4ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 18.8ms
# Speed: 1.9ms preprocess, 18.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 18.9ms
# Speed: 2.2ms preprocess, 18.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 18.8ms
# Speed: 2.0ms preprocess, 18.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 birds, 19.0ms
# Speed: 2.6ms preprocess, 19.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 dog, 18.9ms
# Speed: 2.2ms preprocess, 18.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 birds, 1 person, 20.4ms
# Speed: 2.6ms preprocess, 20.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.7ms
# Speed: 1.9ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 20.1ms
# Speed: 2.8ms preprocess, 20.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.4ms
# Speed: 2.2ms preprocess, 20.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 1 person, 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 3.0ms preprocess, 20.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 dog, 1 person, 20.4ms
# Speed: 2.6ms preprocess, 20.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.0ms
# Speed: 2.7ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 3.5ms preprocess, 20.6ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.7ms
# Speed: 3.8ms preprocess, 20.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.5ms
# Speed: 3.2ms preprocess, 21.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.7ms preprocess, 20.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.3ms preprocess, 20.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 2.5ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Speed: 2.0ms preprocess, 20.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.6ms preprocess, 20.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Speed: 2.0ms preprocess, 20.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.3ms preprocess, 20.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.8ms
# Speed: 3.1ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 1.8ms preprocess, 20.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Speed: 2.8ms preprocess, 20.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.2ms
# Speed: 3.2ms preprocess, 21.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.5ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 2.7ms preprocess, 20.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.9ms
# Speed: 1.9ms preprocess, 19.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 person, 20.2ms
# Speed: 2.8ms preprocess, 20.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.5ms preprocess, 20.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.4ms preprocess, 20.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 chair, 1 person, 20.0ms
# Speed: 2.6ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 1.8ms preprocess, 20.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 boat, 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 4.1ms preprocess, 20.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 boat, 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.3ms preprocess, 20.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.4ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.4ms preprocess, 20.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 20.1ms
# Speed: 2.3ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 1.8ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 boat, 2 persons, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 boat, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.1ms
# Speed: 2.4ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.3ms
# Speed: 1.8ms preprocess, 20.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 19.9ms
# Speed: 1.8ms preprocess, 19.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 19.9ms
# Speed: 1.8ms preprocess, 19.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.2ms
# Speed: 2.4ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.4ms
# Speed: 2.4ms preprocess, 20.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 2 persons, 20.3ms
# Speed: 2.5ms preprocess, 20.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.3ms
# Speed: 2.4ms preprocess, 20.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.7ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 aeroplanes, 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 20.1ms
# Speed: 3.3ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.9ms
# Speed: 1.9ms preprocess, 19.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 19.9ms
# Speed: 1.8ms preprocess, 19.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 20.0ms
# Speed: 2.8ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.3ms
# Speed: 2.3ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 2.3ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.1ms
# Speed: 2.6ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 1.8ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 1.8ms preprocess, 20.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 3.1ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.6ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.5ms preprocess, 20.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.7ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.2ms
# Speed: 2.7ms preprocess, 20.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.3ms
# Speed: 2.0ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.9ms
# Speed: 2.6ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 19.9ms
# Speed: 2.3ms preprocess, 19.9ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 1.9ms preprocess, 20.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.9ms
# Speed: 1.8ms preprocess, 19.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.5ms preprocess, 20.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Speed: 3.9ms preprocess, 20.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.5ms
# Speed: 3.3ms preprocess, 20.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 21.0ms
# Speed: 3.2ms preprocess, 21.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.4ms
# Speed: 2.6ms preprocess, 20.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.5ms
# Speed: 3.9ms preprocess, 20.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.4ms preprocess, 20.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 car, 2 persons, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 2.4ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 1.9ms preprocess, 20.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 1.8ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.4ms
# Speed: 2.2ms preprocess, 20.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.8ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.2ms
# Speed: 1.9ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.9ms
# Speed: 2.8ms preprocess, 19.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 birds, 1 person, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 bird, 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 bird, 20.0ms
# Speed: 2.2ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.1ms
# Speed: 2.9ms preprocess, 20.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Speed: 2.1ms preprocess, 20.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 horse, 1 person, 20.7ms
# Speed: 3.1ms preprocess, 20.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.5ms preprocess, 20.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 19.9ms
# Speed: 2.1ms preprocess, 19.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 birds, 2 persons, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.1ms
# Speed: 2.6ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.1ms preprocess, 20.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.1ms
# Speed: 1.8ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.3ms
# Speed: 3.2ms preprocess, 20.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.1ms preprocess, 20.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 2.3ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.1ms
# Speed: 1.8ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.4ms preprocess, 20.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.7ms
# Speed: 2.3ms preprocess, 20.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.8ms preprocess, 20.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 boat, 20.0ms
# Speed: 1.7ms preprocess, 20.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 19.9ms
# Speed: 2.2ms preprocess, 19.9ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.0ms
# Speed: 2.6ms preprocess, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.4ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.3ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 3.0ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.1ms preprocess, 20.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 19.9ms
# Speed: 2.3ms preprocess, 19.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.3ms
# Speed: 2.8ms preprocess, 20.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.8ms
# Speed: 2.2ms preprocess, 20.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.0ms preprocess, 20.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.8ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.7ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 boat, 1 person, 20.3ms
# Speed: 1.9ms preprocess, 20.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.4ms preprocess, 20.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 boats, 1 person, 20.1ms
# Speed: 1.9ms preprocess, 20.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 car, 1 person, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 boat, 1 person, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.1ms
# Speed: 2.2ms preprocess, 20.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.6ms
# Speed: 1.9ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 3.2ms preprocess, 20.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.7ms
# Speed: 2.0ms preprocess, 20.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.7ms
# Speed: 2.0ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.8ms
# Speed: 1.9ms preprocess, 20.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.9ms
# Speed: 3.9ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 1.9ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.5ms
# Speed: 2.8ms preprocess, 20.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.7ms
# Speed: 2.6ms preprocess, 20.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.5ms
# Speed: 1.9ms preprocess, 20.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 20.9ms
# Speed: 2.7ms preprocess, 20.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.8ms
# Speed: 2.7ms preprocess, 20.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.9ms
# Speed: 2.6ms preprocess, 20.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 20.8ms
# Speed: 3.8ms preprocess, 20.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 1.9ms preprocess, 20.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.8ms
# Speed: 2.4ms preprocess, 20.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 20.8ms
# Speed: 2.2ms preprocess, 20.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 20.5ms
# Speed: 2.2ms preprocess, 20.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.8ms
# Speed: 2.9ms preprocess, 20.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 20.6ms
# Speed: 2.3ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 21.0ms
# Speed: 2.7ms preprocess, 21.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 4 persons, 20.7ms
# Speed: 2.2ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 21.2ms
# Speed: 2.2ms preprocess, 21.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.5ms
# Speed: 2.1ms preprocess, 20.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.9ms
# Speed: 1.9ms preprocess, 20.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 21.1ms
# Speed: 2.6ms preprocess, 21.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.7ms
# Speed: 3.1ms preprocess, 20.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 21.0ms
# Speed: 3.4ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 21.5ms
# Speed: 2.9ms preprocess, 21.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 20.9ms
# Speed: 3.4ms preprocess, 20.9ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 21.0ms
# Speed: 2.6ms preprocess, 21.0ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.0ms preprocess, 20.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 2 persons, 21.0ms
# Speed: 2.6ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.6ms
# Speed: 2.9ms preprocess, 20.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 1.7ms preprocess, 20.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.7ms
# Speed: 2.5ms preprocess, 20.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 person, 20.6ms
# Speed: 1.8ms preprocess, 20.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 1.9ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.7ms
# Speed: 3.5ms preprocess, 20.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.9ms
# Speed: 2.0ms preprocess, 20.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.6ms
# Speed: 2.1ms preprocess, 20.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 1.9ms preprocess, 20.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.5ms
# Speed: 1.9ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.7ms
# Speed: 2.7ms preprocess, 20.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.6ms
# Speed: 2.1ms preprocess, 20.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.6ms
# Speed: 2.2ms preprocess, 20.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.8ms
# Speed: 2.5ms preprocess, 20.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.5ms
# Speed: 2.0ms preprocess, 20.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 20.7ms
# Speed: 2.3ms preprocess, 20.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.7ms
# Speed: 2.9ms preprocess, 20.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.9ms
# Speed: 2.2ms preprocess, 20.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 20.7ms
# Speed: 2.2ms preprocess, 20.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 20.8ms
# Speed: 1.9ms preprocess, 20.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 21.0ms
# Speed: 3.2ms preprocess, 21.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 140.3ms
# Speed: 6.9ms preprocess, 140.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 65.0ms
# Speed: 6.2ms preprocess, 65.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 17.6ms
# Speed: 1.7ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 17.6ms
# Speed: 1.7ms preprocess, 17.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 2 birds, 1 person, 17.8ms
# Speed: 2.3ms preprocess, 17.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 2 persons, 25.3ms
# Speed: 3.3ms preprocess, 25.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 17.2ms
# Speed: 4.5ms preprocess, 17.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 17.5ms
# Speed: 2.7ms preprocess, 17.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 birds, 1 person, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 16.1ms
# Speed: 2.3ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 bird, 1 person, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 birds, 3 persons, 16.2ms
# Speed: 2.0ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 aeroplane, 1 bird, 2 persons, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 3 persons, 16.2ms
# Speed: 2.7ms preprocess, 16.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 4 persons, 16.1ms
# Speed: 2.9ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 16.3ms
# Speed: 2.4ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 17.6ms
# Speed: 3.1ms preprocess, 17.6ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.2ms
# Speed: 2.3ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 16.4ms
# Speed: 2.9ms preprocess, 16.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 2 persons, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bird, 1 person, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.6ms
# Speed: 2.6ms preprocess, 16.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.3ms
# Speed: 2.4ms preprocess, 16.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 2.0ms preprocess, 16.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 1.9ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 2.2ms preprocess, 16.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.3ms
# Speed: 2.3ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.3ms
# Speed: 2.5ms preprocess, 16.3ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.5ms
# Speed: 2.7ms preprocess, 16.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.3ms
# Speed: 2.2ms preprocess, 16.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 16.5ms
# Speed: 3.2ms preprocess, 16.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
